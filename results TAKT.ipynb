# %%
import matplotlib.pyplot as plt
import matplotlib.lines as lines
import time
import numpy as np
import pandas as pd
import math

# %%
# base
db = {
    1: 70.10000000000001,
    2: 35.2,
    3: 23.5,
    4: 18.4,
    5: 14.6,
    6: 12.3,
    7: 11.0,
    8: 9.7,
    9: 8.6,
    10: 8.199999999999898,
    11: 8.199999999999898,
    12: 8.199999999999898,
    13: 8.199999999999898,
    14: 8.199999999999898,
    15: 8.199999999999898
}

# %%
# divided by 2
dd = {
    1: 70.10000000000001,
    2: 35.1,
    3: 23.5,
    4: 17.900000000000002,
    5: 14.3,
    6: 12.1,
    7: 10.500000000000002,
    8: 9.3,
    9: 8.15,
    10: 7.5,
    11: 7.1,
    12: 6.45,
    13: 6.1000000000000005,
    14: 5.599999999999997,
    15: 5.349999999999253,
#     16: 5.100000000000005,
#     17: 5.0,
#     18: 4.55,
#     19: 4.35,
#     20: 4.099999999999949,
#     21: 4.099999999999949,
}

# %%
# combined
dc = {
    1: 70.1,
    2: 39.3,
    3: 27.699999999999996,
    4: 22.0,
    5: 20.799999999999997,
    6: 20.799999999999997,
    7: 20.799999999999997,
    8: 20.799999999999997,
    9: 20.799999999999997
}

# %%
plt.scatter(db.keys(), db.values())
plt.plot(db.keys(), db.values())

plt.scatter(dd.keys(), dd.values())
plt.plot(dd.keys(), dd.values())

plt.scatter(dc.keys(), dc.values())
plt.plot(dc.keys(), dc.values())

plt.show()

# %%
db2 = dict(db)
dc2 = dict(dc)
dd2 = dict(dd)

# %%
for k in db2:
    db2[k] = math.ceil(db[k])*(k+4-1)
for k in dc2:
    dc2[k] = math.ceil(dc[k])*(k+4-1)
for k in dd2:
    dd2[k] = math.ceil(dd[k])*(k+4-1)

# %%
plt.scatter(db2.keys(), db2.values(), label='grid size = (8,9)')
plt.plot(db2.keys(), db2.values())

plt.scatter(dd2.keys(), dd2.values(), label='grid size = (8,18)')
plt.plot(dd2.keys(), dd2.values())

plt.scatter(dc2.keys(), dc2.values(), label='grid size = (3,3)')
plt.plot(dc2.keys(), dc2.values())

plt.legend()

plt.show()
